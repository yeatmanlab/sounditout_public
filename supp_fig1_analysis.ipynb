# %% [markdown]
# ## Study 2 - Validation analysis and Supplmental Fig 1
# #### Patrick M. Donnelly
# #### University of Washington
# #### 16 November 2020

# %%
# import necessary databases and libraries
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
sns.set(font='Times New Roman')
sns.set_style("whitegrid")

# %%
# import data
data = pd.read_csv('data/study2/study2_validationdata.csv');

# %%
g = sns.violinplot(x="Condition", y="Correct", data = data, inner='quartile')
g = sns.swarmplot(x="Condition", y="Correct", data = data, color='black')
g.set_title("", fontsize=12)
g.set_xlabel("Group", fontsize=12)
g.set_ylabel("Number correct", fontsize=12)
g.set_xticklabels(["Pigs & Suns", "Igloos & Umbrellas"], fontsize=12)

#save file
plt.savefig('pigsv_violin.png',dpi=300,transparent=True)

# %%
stats.ttest_ind(*data.groupby(['Condition'])['Correct'].apply(lambda x:list(x)))
# Out:
# Ttest_indResult(statistic=-0.24948078863995762, pvalue=0.8055332841827285)
